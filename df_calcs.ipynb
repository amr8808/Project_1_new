# %%
import pandas as pd

df = pd.read_csv('2021allstar.csv')

# %%
df.head()
# Out:
#       Player Name                 Set  Series       Play  \
# 0  Damian Lillard  2021 All-Star Game       2  3 Pointer
# 1  Damian Lillard  2021 All-Star Game       2  3 Pointer
# 2  Damian Lillard  2021 All-Star Game       2  3 Pointer
# 3  Damian Lillard  2021 All-Star Game       2  3 Pointer
# 4  Damian Lillard  2021 All-Star Game       2  3 Pointer
#
#               Date of Moment         Team  Circulation Count  Serial  \
# 0  2021-03-08 01:00:00+00:00  Team LeBron                431     112
# 1  2021-03-08 01:00:00+00:00  Team LeBron                431     381
# 2  2021-03-08 01:00:00+00:00  Team LeBron                431     116
# 3  2021-03-08 01:00:00+00:00  Team LeBron                431      18
# 4  2021-03-08 01:00:00+00:00  Team LeBron                431      36
#
#    Purchase Price           Buyer        Seller           Transaction Date  \
# 0            1499       zero_edge  socratesyear  2021-04-09 11:49:38+00:00
# ...

# %%
df.columns
# Out:
# Index(['Player Name', 'Set', 'Series', 'Play', 'Date of Moment', 'Team',
#        'Circulation Count', 'Serial', 'Purchase Price', 'Buyer', 'Seller',
#        'Transaction Date', 'Top Shot Debut', 'Rookie Premiere', 'Rookie Mint',
#        'Rookie Year', 'Edition State', 'Play ID', 'Set ID', 'Top Shot Link'],
#       dtype='object')

# %%
cuteknick = df['Buyer']== 'Cuteknick'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-d5613a9f375c> in <module>
#       1 cuteknick = df['Buyer']== 'Cuteknick'
# ----> 2 df.sum(([cuteknick]('Purchase Price')))
#
# TypeError: 'list' object is not callable
